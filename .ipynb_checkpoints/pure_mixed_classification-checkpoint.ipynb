# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
import imghdr
import matplotlib.pyplot as plt

# %%
image_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
data_dir = 'data'

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts:
                print("Image not in ext list {}".format(image_path))
                os.remove(image_path)
        except Exception as e:
            print("Issue with image {}".format(image_path))

# %% [markdown]
# # Load Data

# %%
import numpy as np

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 48 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
data_iterator

# %%
batch = data_iterator.next()

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %% [markdown]
# # 2. Preprocess Data

# %% [markdown]
# ## 2.1 Scaling images

# %%
data = data.map(lambda x,y: (x/255, y))

# %% [markdown]
# ## 2.2 Split Data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size + val_size).take(test_size)

# %% [markdown]
# # 3. Model

# %% [markdown]
# ## 3.1 Build the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3.2 Train the model

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 1/1 [==============================] - 8s 8s/step - loss: 0.6377 - accuracy: 0.7812 - val_loss: 1.4623 - val_accuracy: 0.8750
# Epoch 2/20
# 1/1 [==============================] - 1s 841ms/step - loss: 1.8519 - accuracy: 0.8438 - val_loss: 2.7053 - val_accuracy: 0.6250
# Epoch 3/20
# 1/1 [==============================] - 1s 823ms/step - loss: 1.3439 - accuracy: 0.8125 - val_loss: 0.7140 - val_accuracy: 0.7500
# Epoch 4/20
# 1/1 [==============================] - 1s 823ms/step - loss: 0.5643 - accuracy: 0.8125 - val_loss: 0.6702 - val_accuracy: 0.8125
# Epoch 5/20
# 1/1 [==============================] - 1s 810ms/step - loss: 0.6606 - accuracy: 0.8125 - val_loss: 0.6970 - val_accuracy: 0.1875
# Epoch 6/20
# 1/1 [==============================] - 1s 819ms/step - loss: 0.7107 - accuracy: 0.1875 - val_loss: 0.6556 - val_accuracy: 0.8750
# Epoch 7/20
# 1/1 [==============================] - 1s 958ms/step - loss: 0.6348 - accuracy: 0.8125 - val_loss: 0.5397 - val_accuracy: 0.8750
# Epoch 8/20
# 1/1 [==============================] - 1s 989ms/step - loss: 0.5839 - accuracy: 0.8438 - val_loss: 0.5126 - val_accuracy: 0.7500
# Epoch 9/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.5729 - accuracy: 0.7500 - val_loss: 0.6811 - val_accuracy: 0.7500
# Epoch 10/20
# 1/1 [==============================] - 1s 971ms/step - loss: 0.5286 - accuracy: 0.8125 - val_loss: 0.7685 - val_accuracy: 0.6250
# Epoch 11/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.4127 - accuracy: 0.8438 - val_loss: 0.5777 - val_accuracy: 0.6875
# Epoch 12/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.4624 - accuracy: 0.8125 - val_loss: 0.3041 - val_accuracy: 0.9375
# Epoch 13/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.5137 - accuracy: 0.7500 - val_loss: 0.4106 - val_accuracy: 0.8750
# Epoch 14/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.3915 - accuracy: 0.8750 - val_loss: 0.5336 - val_accuracy: 0.7500
# Epoch 15/20
# 1/1 [==============================] - 1s 976ms/step - loss: 0.4598 - accuracy: 0.7812 - val_loss: 0.7519 - val_accuracy: 0.5625
# Epoch 16/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.4656 - accuracy: 0.7812 - val_loss: 0.3577 - val_accuracy: 0.8125
# Epoch 17/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.4218 - accuracy: 0.7812 - val_loss: 0.4370 - val_accuracy: 0.7500
# Epoch 18/20
# 1/1 [==============================] - 1s 999ms/step - loss: 0.3867 - accuracy: 0.8750 - val_loss: 0.3842 - val_accuracy: 0.8125
# Epoch 19/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.4369 - accuracy: 0.7812 - val_loss: 0.4315 - val_accuracy: 0.8125
# Epoch 20/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.4431 - accuracy: 0.7500 - val_loss: 0.2550 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32)

# %%
img = cv2.imread('F:\image classification\data\data-happy\A_Sep20_14_1189155141.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
yhat
# Out:
# array([[0.97455525]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Sad
